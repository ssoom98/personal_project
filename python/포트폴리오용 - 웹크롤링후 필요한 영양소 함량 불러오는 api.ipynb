# %%
# 파일 불러오기
import pandas as pd
df_reci = pd.read_csv(r'../data/recipe_list.csv',encoding='utf_8')
df_reci
# Out:
#       레시피구분        레시피명                열량          식재료명  식재료양
# 0       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal       새우(꽃새우)    8g
# 1       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal           참기름    4g
# 2       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal         해바라기씨    3g
# 3       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal            물엿  1.5g
# 4       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal      간장(양조간장)    1g
# ...     ...         ...               ...           ...   ...
# 41574    국류     김치콩비지찌개  열량 : 102.46 kcal   멸치(큰멸치, 대멸)    2g
# 41575    국류     김치콩비지찌개  열량 : 102.46 kcal            마늘    1g
# 41576    국류     김치콩비지찌개  열량 : 102.46 kcal            생강  0.1g
# 41577   무침류   브로콜리/초고추장    열량 : 33.9 kcal          브로콜리   40g
# 41578   무침류   브로콜리/초고추장    열량 : 33.9 kcal  초고추장(요리초고추장)   10g
#
# [41579 rows x 5 columns]

# %%
# 표준 레시피 내에서 필요한 식재료만 꺼내기
used_name=pd.DataFrame(df_reci['식재료명'].drop_duplicates()).reset_index(drop=True)

pd.options.display.max_rows=len(used_name)
used_name
# Out:
#                     식재료명
# 0                새우(꽃새우)
# 1                    참기름
# 2                  해바라기씨
# 3                     물엿
# 4               간장(양조간장)
# 5                  혼합식용유
# 6                설탕(백설탕)
# 7                  깨(참깨)
# 8                     마늘
# 9                 멥쌀(백미)
# 10                    달걀
# 11                   양배추
# 12                   오징어
# 13                   새우살
# 14                 돈가스소스
# 15                  부침가루
# 16                  숙주나물
# 17                    양파
# 18                 파(쪽파)
# 19              콩기름(대두유)
# 20                   김가루
# 21              김치(총각김치)
# 22              김치(배추김치)
# 23               김치(깍두기)
# 24            사과(부사, 후지)
# 25                   바나나
# 26     토마토(방울토마토(체리토마토))
# 27                  마요네즈
# 28              치즈(눈꽃치즈)
# 29               설탕(황설탕)
# 30                   건포도
# 31                    땅콩
# 32              소금(구운소금)
# 33                달걀(전란)
# 34                    당근
# 35               닭가슴살파우치
# 36                  게맛살채
# 37              소금(고운소금)
# 38              김치(열무김치)
# 39               보리(찰보리)
# 40                    보리
# 41               호박(애호박)
# 42               상추(꽃상추)
# 43            파스타(스파게티면)
# 44                스파게티소스
# 45                   토마토
# 46          토마토통조림(페이스트)
# 47             토마토통조림(홀)
# 48               피망(청피망)
# 49                  표고버섯
# 50                 양송이버섯
# 51             분말(파슬리분말)
# 52             육수(동치미육수)
# 53                    소면
# 54                   깐달걀
# 55                    무쌈
# 56                    오이
# 57                  고춧가루
# 58                  팽이버섯
# 59               피망(홍피망)
# 60              죽순통조림(채)
# 61                    부추
# 62                   굴소스
# 63              전분(감자전분)
# 64                 파(대파)
# 65                    후추
# 66              소금(볶은소금)
# 67         큰느타리버섯(새송이버섯)
# 68                    간장
# 69               물엿(쌀물엿)
# 70          배추(얼갈이, 단배추)
# 71                무(조선무)
# 72             콩가루(날콩가루)
# 73                    된장
# 74                   다시마
# 75                    두부
# 76                    냉이
# 77     고추(풋고추(청고추, 개량종))
# 78         고추(붉은고추(홍고추))
# 79              분말(카레분말)
# 80                    감자
# 81                  송이버섯
# 82                   완두콩
# 83          동그랑땡(채소동그랑땡)
# 84               두부(순두부)
# 85                   청국장
# 86          고추(풋고추(청고추))
# 87               소금(천일염)
# 88              완자(두부완자)
# 89              멥쌀(구분도미)
# 90                   돌나물
# 91                    달래
# 92                   고사리
# 93                   도라지
# 94                   깨소금
# 95                   매생이
# 96                    생강
# 97               배추(우거지)
# 98                   고추장
# 99                   수제비
# 100                 들깨가루
# 101            간장(죽염국간장)
# 102                  어육햄
# 103                 브로콜리
# 104             허니머스터드소스
# 105                 참깨가루
# 106           옹심이(감자옹심이)
# 107                   미역
# 108         파프리카(주황파프리카)
# 109         파프리카(적색파프리카)
# 110         파프리카(노랑파프리카)
# 111                  청경채
# 112                고추씨기름
# 113             고추(청양고추)
# 114             식초(양조식초)
# 115                  시금치
# 116             간장(재래간장)
# 117                  들기름
# 118              김치(맛김치)
# 119                 찹쌀가루
# 120              녹두빈대떡가루
# 121           옥수수기름(옥배유)
# 122                    김
# 123                 후리카케
# 124                  빵가루
# 125               스테이크소스
# 126              소금(꽃소금)
# 127                  밀가루
# 128                   유부
# 129                 석이버섯
# 130             식초(사과식초)
# 131              후추(검은색)
# 132               애느타리버섯
# 133            후춧가루(검은색)
# 134                  취나물
# 135             된장(전통된장)
# 136                  콩나물
# 137                   배추
# 138                  매실청
# 139              젓(멸치액젓)
# 140           장아찌(마늘장아찌)
# 141               한우(안심)
# 142                   맛술
# 143               바질(바실)
# 144                    꿀
# 145                 올리브유
# 146                  아몬드
# 147             닭고기(다리살)
# 148       카레(인도풍붉은카레반고형)
# 149            우유(저지방우유)
# 150             분말(칠리분말)
# 151                   사과
# 152         파인애플(골드파인애플)
# 153         토마토(대추방울토마토)
# 154            포도(씨없는포도)
# 155                   키위
# 156                   식혜
# 157                 오리훈제
# 158       드레싱(허니머스터드드레싱)
# 159               젓(새우젓)
# 160              햄(불갈비햄)
# 161             피클(모둠피클)
# 162             피클(오이피클)
# 163           파스타(삼색푸실리)
# 164               옥수수통조림
# 165                토마토케첩
# 166               후추(흰색)
# 167             돼지고기(등심)
# 168              닭고기(가슴)
# 169                떡(꿀떡)
# 170                  양상추
# 171                  치커리
# 172       양배추(적채, 붉은양배추)
# 173                 올리고당
# 174            식초(발사믹식초)
# 175                   우유
# 176             식초(레몬식초)
# 177         파프리카(녹색파프리카)
# 178                 파인애플
# 179             치즈(체다치즈)
# 180             밀가루(중력분)
# 181                   당면
# 182                 목이버섯
# 183                  참나물
# 184                   홍합
# 185      조개(모시조개, 가무락조개)
# 186                   죽순
# 187                 갑오징어
# 188                 무시래기
# 189             육수(사골육수)
# 190               육우(양지)
# 191       토마토(노란대추방울토마토)
# 192                  로메인
# 193                 적겨자잎
# 194                   비트
# 195          발효유(호상요구르트)
# 196                   깻잎
# 197                 아보카도
# 198              파인애플통조림
# 199             과즙음료(레몬)
# 200                  순무잎
# 201           고추장(요리고추장)
# 202         드레싱(블루베리드레싱)
# 203           치커리(적색치커리)
# 204                 블루베리
# 205            김치(배추겉절이)
# 206        멸치(작은멸치, 가이리)
# 207              물엿(황물엿)
# 208                   호두
# 209             전병(메밀전병)
# 210                감귤통조림
# 211         드레싱(이탈리안드레싱)
# 212          장아찌(마늘종장아찌)
# 213                  바게트
# 214           떡갈비(수제떡갈비)
# 215               데리야끼소스
# 216        부추(실부추(영양부추))
# 217              두부(손두부)
# 218        돼지고기(뒷다리, 후지)
# 219                 돼지잡뼈
# 220              호박(단호박)
# 221              크림(생크림)
# 222          수제비(우리밀수제비)
# 223          멸치(큰멸치, 대멸)
# 224                   연어
# 225             포도(캠벨얼리)
# 226                   레몬
# 227            주스(오미자주스)
# 228                  뱅어포
# 229              떡(무지개떡)
# 230             라면(라면사리)
# 231               멥쌀(흑미)
# 232               명태(황태)
# 233                  홍합살
# 234             젓(까나리액젓)
# 235               찹쌀(백미)
# 236               찹쌀(현미)
# 237               타르타르소스
# 238           드레싱(키위드레싱)
# 239            육수(디포리육수)
# 240                  조갯살
# 241               명태(북어)
# 242                   새우
# 243                  옥수수
# 244             오렌지(네이블)
# 245           드레싱(시저드레싱)
# 246                  수정과
# 247                  통계피
# 248              설탕(흑설탕)
# 249                    잣
# 250                   맛살
# 251             어묵(사각어묵)
# 252             분말(겨자분말)
# 253                 사골국물
# 254               한우(양지)
# 255    대두콩(검정콩(흑태, 흑대두))
# 256                   귀리
# 257                   기장
# 258            김치(오이백김치)
# 259              김치(백김치)
# 260             멥쌀(발아현미)
# 261                매실농축액
# 262              김치(동치미)
# 263                   식초
# 264          깨(검정깨(흑임자))
# 265           단무지(한입단무지)
# 266                  꽃맛살
# 267           단무지(꼬들단무지)
# 268               멥쌀(현미)
# 269           곤드레(고려엉겅퀴)
# 270             부추(두메부추)
# 271                고구마줄기
# 272                깨(들깨)
# 273                   근대
# 274                   강황
# 275             만두(갈비만두)
# 276              김치(갓김치)
# 277                   우엉
# 278               육우(설도)
# 279                느타리버섯
# 280                    배
# 281                   생수
# 282               육우(채끝)
# 283    치즈(모짜렐라치즈(스틱형-단))
# 284                   청주
# 285          육우(앞다리, 전지)
# 286                 육우잡뼈
# 287             소금(굵은소금)
# 288           돼지고기(뒷다리살)
# 289              데미글라스소스
# 290                  셀러리
# 291                 달걀지단
# 292        돼지고기(앞다리, 전지)
# 293                  면실유
# 294         호박(애호박(풋호박))
# 295        매끈이고둥통조림(골뱅이)
# 296                   가지
# 297                    밤
# 298                   연근
# 299                 한우사골
# 300                  소잡뼈
# 301                   상추
# 302            김치(열무물김치)
# 303                    쑥
# 304             표고버섯플레이크
# 305                  토란대
# 306                  칼국수
# 307                   멸치
# 308                  쌀국수
# 309            육수(쌀국수육수)
# 310                파(실파)
# 311       드레싱(참깨오리엔탈드레싱)
# 312               육우(안심)
# 313                  떡국떡
# 314               육우(우둔)
# 315                 떡볶이떡
# 316                 칠리소스
# 317              토마토페이스트
# 318                 적포도주
# 319                  베이컨
# 320                   버터
# 321                 월계수잎
# 322                  핫소스
# 323            치즈(파마산치즈)
# 324              배추(알배기)
# 325                   쑥갓
# 326               육우(등심)
# 327           육우(목심, 장정)
# 328              떡(흰가래떡)
# 329            육수(소고기육수)
# 330            전분(옥수수전분)
# 331              육수(닭육수)
# 332               소불고기양념
# 333                우스터소스
# 334                 백포도주
# 335             넥타(생강넥타)
# 336                 겨자소스
# 337                   곤약
# 338        스파게티소스(토마토소스)
# 339                  또띠아
# 340           치즈(모짜렐라치즈)
# 341           치즈(노란체다치즈)
# 342          한우(앞다리, 전지)
# 343             후춧가루(흰색)
# 344                 핫도그빵
# 345               육우(사태)
# 346               고수(향채)
# 347               육우(갈비)
# 348                  소사골
# 349             소(피, 선지)
# 350                 한우잡뼈
# 351                   은행
# 352                두반장소스
# 353           토마토통조림(퓨레)
# 354              정향(클로브)
# 355                   낙지
# 356              감자(알감자)
# 357              숯불바비큐소스
# 358                   토란
# 359                  꼬막살
# 360                   식빵
# 361            게맛살(영양강화)
# 362          크림(38% 유지방)
# 363         육수본(자연재료육수본)
# 364           젓(새우젓(육젓))
# 365         새우(시바새우(중하))
# 366                 동그랑땡
# 367                  주꾸미
# 368                    밥
# 369           닭고기(넓적다리살)
# 370                 알팔파싹
# 371                그릭요거트
# 372           올리브(블랙올리브)
# 373             돼지고기(안심)
# 374             고추(꽈리고추)
# 375                배(신고)
# 376                 가자미살
# 377                  콩가루
# 378            오리고기(집오리)
# 379            어묵(어묵게맛살)
# 380             닭고기(살코기)
# 381             분말(자장분말)
# 382             마요네즈(전란)
# 383               겨자페이스트
# 384              부추(산부추)
# 385                   무싹
# 386             돼지고기(사태)
# 387                 튀김가루
# 388              전분(밀전분)
# 389                   삼치
# 390             돼지고기(목살)
# 391               한우(갈비)
# 392            후르츠칵테일통조림
# 393                   굴비
# 394             만두(고기만두)
# 395           한우(목심, 장정)
# 396               햄(김밥햄)
# 397               한우(등심)
# 398                불고기양념
# 399              땅콩(피땅콩)
# 400        닭고기(가슴살, 안심살)
# 401                  가자미
# 402              수리취(떡취)
# 403                  미더덕
# 404            미나리(돌미나리)
# 405           다시마(뿌리다시마)
# 406         멸치(작은멸치, 지리)
# 407              조기(참조기)
# 408             찹쌀(발아현미)
# 409                   차조
# 410                  모닝빵
# 411                   장어
# 412                  바지락
# 413        탕수육(검은콩고기탕수육)
# 414              식초(배식초)
# 415              간장(어간장)
# 416            피마자(아주까리)
# 417                  미나리
# 418                  고구마
# 419                   연유
# 420                   계피
# 421              보리(늘보리)
# 422            돼지고기(삼겹살)
# 423               차(쌍화차)
# 424                   소주
# 425            후추(검은통후추)
# 426             만두(교자만두)
# 427              닭고기(성계)
# 428                  고등어
# 429            돼지고기(등갈비)
# 430                   아욱
# 431           빵가루(습식빵가루)
# 432                오징어몸통
# 433            오리고기(살코기)
# 434               팥(붉은팥)
# 435              서리태(속청)
# 436              수수(차수수)
# 437              송편(깨송편)
# 438                 오리고기
# 439             무쌈(석류매실)
# 440              닭고기(영계)
# 441                   대추
# 442               인삼(수삼)
# 443              햄(스모그햄)
# 444                 바지락살
# 445         멸치(작은멸치, 소멸)
# 446                   녹두
# 447                 메밀국수
# 448           육수(메밀장국육수)
# 449     치즈(모짜렐라치즈(슬라이스))
# 450             커피(원두커피)
# 451                  시루떡
# 452               치킨튀김가루
# 453             새우(보리새우)
# 454                  치즈볼
# 455             새알(꼬마새알)
# 456         발효유(드링크요구르트)
# 457          크로켓(콩고기크로켓)
# 458               배추(봄동)
# 459             분말(생강분말)
# 460           고추장(고추장소스)
# 461               우동(생면)
# 462        호박(쥬키니(서양호박))
# 463         고춧가루(고운고춧가루)
# 464             곤약(샐러드형)
# 465                   약과
# 466                  건고추
# 467                 논우렁살
# 468             호박(늙은호박)
# 469                  삼치살
# 470                   비지
# 471           우동(사누끼우동면)
# 472              가쓰오우동장국
# 473           어묵(사각어묵꼬치)
# 474       시리얼(곡물(현미)시리얼)
# 475                 크랜베리
# 476                  날치알
# 477             장아찌(오이지)
# 478               한우(사태)
# 479                  전복살
# 480                 전복내장
# 481             돼지고기(갈비)
# 482            어묵(동그란어묵)
# 483              게(붉은대게)
# 484              파래(갈파래)
# 485                코코넛밀크
# 486           새우살(칵테일새우)
# 487             카레(인도카레)
# 488                   수수
# 489                  깻잎순
# 490                   더덕
# 491           고추장(전통고추장)
# 492               묵(청포묵)
# 493               찹쌀(흑미)
# 494               양념치킨소스
# 495               달걀(난황)
# 496                 코다리살
# 497             햄(부대찌개햄)
# 498              묵(도토리묵)
# 499                   병어
# 500             새우(분홍새우)
# 501               한우사골곰탕
# 502                돼지고기햄
# 503             소시지(비엔나)
# 504                탕수육소스
# 505           주스(골드키위주스)
# 506          소시지(프랑크소시지)
# 507           치즈(하얀체다치즈)
# 508                 햄버거빵
# 509             새우살(홍새우)
# 510       케이크(까망베르치즈케이크)
# 511             두부(손순두부)
# 512             베이글(플레인)
# 513             치즈(크림치즈)
# 514                 초고추장
# 515                 돼지등뼈
# 516                  콜라비
# 517            탄산음료(사이다)
# 518             된장(일본된장)
# 519         어묵(종합어묵, 꼬치)
# 520             육수(멸치육수)
# 521                 혼합멸치
# 522             육수(어묵육수)
# 523             어묵(종합어묵)
# 524                  북어채
# 525             된장(찌개된장)
# 526               젓(명란젓)
# 527                   조개
# 528                  모자반
# 529                  유자청
# 530            닭고기(넓적다리)
# 531               소금(솔트)
# 532       튀김(감자튀김(크링클컷))
# 533              양파(적양파)
# 534        드레싱(허니요거트드레싱)
# 535           돈가스(피자돈가스)
# 536              홍합(피홍합)
# 537             우유(초코우유)
# 538                콜리플라워
# 539         스파게티소스(크림소스)
# 540       튀김(닭날개튀김(윙)튀김)
# 541               춘장(자장)
# 542                  파슬리
# 543                 오레가노
# 544             푸딩(포도푸딩)
# 545              포도(청포도)
# 546                   딸기
# 547            콜라비(적콜라비)
# 548                    톳
# 549               무말랭이무침
# 550                  황태채
# 551                사골엑기스
# 552              연두부(꼬마)
# 553              만두(왕만두)
# 554              떡국떡(삼색)
# 555            분말(쇠고기분말)
# 556          바질(바실(개량종))
# 557                 버터스틱
# 558                 피시소스
# 559            주스(구아바주스)
# 560               한우(설도)
# 561             크림(휘핑크림)
# 562               달걀(난백)
# 563                  동태살
# 564                 메추리알
# 565               한우(우둔)
# 566                  머위대
# 567                  연두부
# 568                게(대게)
# 569               닭가슴살치킨
# 570         춘장(볶음춘장(자장))
# 571              오이(재래종)
# 572                  미트볼
# 573              소금(정제염)
# 574        된장(양조된장(개량식))
# 575            다채(그린비타민)
# 576                 고등어살
# 577               햄(쵸핑햄)
# 578            새우볼(통새우볼)
# 579                 임연수살
# 580            우유(검은콩우유)
# 581           치커리(녹색치커리)
# 582             죽순통조림(편)
# 583             양송이버섯통조림
# 584                   당귀
# 585             주스(사과주스)
# 586                   수박
# 587             곤약(깍두기형)
# 588                   명란
# 589                닭다리훈제
# 590                 조랭이떡
# 591                   쫄면
# 592                   어묵
# 593                   대구
# 594             오이(가시오이)
# 595                  탕수육
# 596             마일드참치통조림
# 597                소갈비양념
# 598           탕수육(찹쌀탕수육)
# 599       전분(감자전분(칼슘강화))
# 600          소시지(매운콩소시지)
# 601          스테이크(찹스테이크)
# 602            떡(콩고물인절미)
# 603                  소라살
# 604      치즈(모짜렐라치즈(구슬형))
# 605           수프(브로콜리수프)
# 606       스테이크(두부함박스테이크)
# 607                토마토소스
# 608                게(꽃게)
# 609         볼락(장문볼락, 적어)
# 610               떡(인절미)
# 611             당면(납작당면)
# 612              스위트칠리소스
# 613              복숭아(천도)
# 614           감귤(금귤, 낑깡)
# 615           참다랑어살(참치살)
# 616              와사비페이스트
# 617           다채(그린비타민)싹
# 618             물엿(쌀황물엿)
# 619     튀김(감자튀김(후렌치후라이))
# 620          미트볼(닭고기미트볼)
# 621      샌드위치(햄, 치즈샌드위치)
# 622             어묵(잡채어묵)
# 623         군만두(치즈타코군만두)
# 624           돈가스(미니돈가스)
# 625             국수(중국국수)
# 626                 땅콩버터
# 627             오징어(진미채)
# 628          닭고기(다리, 북채)
# 629                  잔대싹
# 630                감(단감)
# 631                  아귀살
# 632             만두(납작만두)
# 633           돼지고기햄(본레스)
# 634            양상추(꽃양상추)
# 635           홀그레인머스터드소스
# 636                   석류
# 637                 가다랑어
# 638             식초(매실식초)
# 639             어묵(치즈어묵)
# 640            갯나물(세발나물)
# 641                  골뱅이
# 642             당근(꼬마당근)
# 643             육수(냉면육수)
# 644       어묵(막대모양어묵, 꼬치)
# 645                치킨파우더
# 646           올리브(그린올리브)
# 647                  연어살
# 648         드레싱(오리엔탈드레싱)
# 649                  오렌지
# 650             두부(마파두부)
# 651               잼(딸기잼)
# 652              만두(물만두)
# 653                 비름나물
# 654              쌈장(혼합장)
# 655      고추(오이고추, 아삭이고추)
# 656                  깐호두
# 657                  토종닭
# 658                 꼬시래기
# 659              오이(청오이)
# 660              만두(손만두)
# 661                  닭꼬치
# 662                 무말랭이
# 663               묵(메밀묵)
# 664          소시지(불고기비엔나)
# 665                 파래돌김
# 666              꼬막(새꼬막)
# 667              소금(맛소금)
# 668              블루베리통조림
# 669            아스파라거스통조림
# 670           소시지(수제소시지)
# 671                  임연수
# 672              상추(쫑상추)
# 673                 미꾸라지
# 674                 산초가루
# 675                  마늘종
# 676                 미역줄기
# 677                   갈치
# 678                   리치
# 679               돼지갈비양념
# 680           치즈(구슬모양치즈)
# 681                브로콜리싹
# 682                   파래
# 683                 치킨텐더
# 684         유채(동초, 겨울초)싹
# 685             당면(자른당면)
# 686              주스(배주스)
# 687                  복분자
# 688            김치(오이소박이)
# 689             김치(나박김치)
# 690                 옥수수알
# 691                 크림수프
# 692            소면(우리밀백밀)
# 693               인삼(미삼)
# 694             튀김(감자튀김)
# 695      스테이크(소고기함박스테이크)
# 696         동그랑땡(고기동그랑땡)
# 697           장아찌(고추장아찌)
# 698                  동태알
# 699                  대구알
# 700                 명태곤이
# 701            어묵(꼬불이어묵)
# 702         찹쌀가루(건식찹쌀가루)
# 703                  진달래
# 704       시금치(섬초(비금시금치))
# 705                    마
# 706           분말(크림수프분말)
# 707              젓(오징어젓)
# 708            분말(와사비분말)
# 709      청국장(낫토(일본식청국장))
# 710              중화풍볶음소스
# 711         소시지(닭고기햄비엔나)
# 712      스테이크(담양떡갈비스테이크)
# 713                 참소라살
# 714                바비큐소스
# 715              상추(적상추)
# 716                   명태
# 717               묵(녹두묵)
# 718                 오만둥이
# 719          핫도그(우리밀핫도그)
# 720                   망고
# 721       혼합주스(망고치아씨드주스)
# 722              명태(코다리)
# 723               사워크림소스
# 724                   해삼
# 725         스테이크(치킨스테이크)
# 726          피자소스(고르곤졸라)
# 727           미트볼(두부미트볼)
# 728             고추냉이페이스트
# 729       스테이크(마늘함박스테이크)
# 730                 생선가스
# 731           돈가스(감자돈가스)
# 732                찰옥수수알
# 733                탄두리치킨
# 734           군만두(잡채군만두)
# 735                  강낭콩
# 736                   꽁치
# 737          또띠아(밀, 8인치)
# 738                마늘바게트
# 739                  갈치살
# 740                   전복
# 741                  동죽살
# 742                  호박씨
# 743               명태(동태)
# 744          소시지(비엔나소시지)
# 745              젓(꼴뚜기젓)
# 746               닭고기(봉)
# 747                 메밀가루
# 748     장아찌(울외장아찌(나라쓰게))
# 749               젓(갈치젓)
# 750                  마른김
# 751                  백진미
# 752                  해파리
# 753              파래(청파래)
# 754          넝쿨강낭콩(울타리콩)
# 755               김(구운김)
# 756               묵(동부묵)
# 757          명엽채(명태, 동태)
# 758            소면(우리밀통밀)
# 759                 동태곤이
# 760           소시지(옛날소시지)
# 761                  동태포
# 762                  현미유
# 763                만가닥버섯
# 764                    햄
# 765           젓(새우젓(추젓))
# 766              두부(전두부)
# 767            가자미(참가자미)
# 768                  와사비
# 769                  호밀빵
# 770        샌드위치(닭고기샌드위치)
# 771        닭고기(다리, 북채)훈제
# 772             전복(오분자기)
# 773        드레싱(참깨흑임자드레싱)
# 774        샌드위치(소고기샌드위치)
# 775                  김자반
# 776         샌드위치(몬테크리스토)
# 777         샌드위치(참치샌드위치)
# 778             우유(딸기우유)
# 779                  닭갈비
# 780          발효유(액상요구르트)
# 781             주스(포도주스)
# 782                흑임자가루
# 783                  누룽지
# 784                 곤약국수
# 785             어묵(구멍어묵)
# 786                   춘권
# 787              김(구운돌김)
# 788                  풋마늘
# 789                  대구살
# 790              가다랑어통조림
# 791             새우살(백새우)
# 792   소시지(꽃모양비엔나(칼집비엔나))
# 793         홀커넬스타일옥수수통조림
# 794       소시지(프랑크푸르트소시지)
# 795              순대(찰순대)
# 796          육수본(가쓰오육수본)
# 797           소시지(칼집비엔나)
# 798            튀김(김말이튀김)
# 799                  군만두
# 800            멜론(머스크멜론)
# 801        모시조개살(가무락조개살)
# 802                   동부
# 803             찹쌀(발아흑미)
# 804                  렌틸콩
# 805                아이스크림
# 806        명이나물절임(산마늘절임)
# 807                  콩자반
# 808                   열무
# 809       시루떡(찰시루떡, 콩고물)
# 810                 떡꼬치떡
# 811                떡(절편)
# 812                  핫도그
# 813                 소보루빵
# 814       페이스트리(시나몬패스츄리)
# 815             냉면(함흥냉면)
# 816             닭꼬치(가슴살)
# 817                   자두
# 818           꽈배기(찹쌀꽈배기)
# 819           핫도그(감자핫도그)
# 820          군만두(오징어군만두)
# 821            옥수수(찰옥수수)
# 822            식빵(토스트식빵)
# 823        또띠아(우리밀, 6인치)
# 824             수프(양파수프)
# 825            수프(단호박수프)
# 826                   문어
# 827     유채(동초, 겨울초(개량종))
# 828             와인숙성돼지훈제
# 829                  마늘빵
# 830                  포항초
# 831                  방어살
# 832                  재첩살
# 833        포도(청포도(시들러스))
# 834        어묵(두부어묵, 어두부)
# 835                   순대
# 836                  대두콩
# 837               묵(우무묵)
# 838                  무화과
# 839           에이드(자몽에이드)
# 840         튀김(감자튀김(벌집))
# 841          크로켓(고구마크로켓)
# 842            파스타(마카로니)
# 843                  다슬기
# 844                 돌김자반
# 845         멸치(중멸치, 가이리)
# 846             완자(갈비완자)
# 847            튀김(오징어튀김)
# 848             시루떡(백설기)
# 849         오이(늙은오이(노각))
# 850                   돌김
# 851              상추(청상추)
# 852                   국수
# 853          떡(개피떡, 바람떡)
# 854              데리야끼닭꼬치
# 855          햄(쵸핑햄(8mm))
# 856          시리얼(아몬드시리얼)
# 857        시리얼(곡물(쌀)시리얼)
# 858              차(결명자차)
# 859             완자(새우완자)
# 860           피클(비트뿌리피클)
# 861              피클(무피클)
# 862                  고춧잎
# 863            우유(바나나우유)
# 864                포(쥐포)
# 865                   유자
# 866               아스파라거스
# 867        어묵(방울어묵(볼어묵))
# 868          드레싱(프렌치드레싱)
# 869            과즙음료(구아바)
# 870             닭고기(닭날개)
# 871            멜론(파파야멜론)
# 872                  단무지
# 873                   와플
# 874                  초코볼
# 875             시럽(초코시럽)
# 876              오이(백오이)
# 877                    굴
# 878        간장(참치액간장(쯔유))
# 879                   우동
# 880            주스(오렌지주스)
# 881           돈가스(등심돈가스)
# 882       돈가스소스(일식돈가스소스)
# 883             산적(모둠산적)
# 884         혼합주스(홍삼포도주스)
# 885              식초(쌀식초)
# 886            주스(청포도주스)
# 887                 방풍나물
# 888                   앵두
# 889            완자(불고기완자)
# 890               타코야끼소스
# 891                 꿔바로우
# 892          올리고당(쌀올리고당)
# 893                감(곶감)
# 894             분말(마늘분말)
# 895           주스(애플망고주스)
# 896         햄(쵸핑햄(10mm))
# 897                 우엉조림
# 898            탄산음료(탄산수)
# 899           김치(고들빼기김치)
# 900              두릅(참두릅)
# 901             어묵(호박어묵)
# 902             어묵(우엉어묵)
# 903             어묵(양파어묵)
# 904                 순무뿌리
# 905              미역(물미역)
# 906              떡(모둠찰떡)
# 907               감(말랭이)
# 908                   재첩
# 909                오리불고기
# 910              멥쌀(나라미)
# 911                   두유
# 912         핫도그(미니치즈핫도그)
# 913               새우(대하)
# 914            돼지고기햄(등심)
# 915              김치(파김치)
# 916       단무지(반달슬라이스단무지)
# 917                 밤통조림
# 918            주스(한라봉주스)
# 919                아이스홍시
# 920            튀김(왕새우튀김)
# 921              차(민들레차)
# 922             치즈(자연치즈)
# 923                 새우가스
# 924                 클로렐라
# 925               갑오징어몸통
# 926       치즈(자연치즈(피자치즈))
# 927                 피자소스
# 928              냉면(물냉면)
# 929            식초(화이트식초)
# 930             두부(초당두부)
# 931               차(매실차)
# 932                 카레소스
# 933             주스(자몽주스)
# 934                   자몽
# 935          미역(곰피, 쇠미역)
# 936              만주(밤만주)
# 937                   곤이
# 938           탕수육(등심탕수육)
# 939            깻잎지절임(간장)
# 940           장아찌(매실장아찌)
# 941                  원추리
# 942               차(생강차)
# 943              복숭아(황도)
# 944                   참외
# 945             돼지고기햄통조림
# 946                 치킨가스
# 947                 캐슈너트
# 948     드레싱(사우전드아일랜드드레싱)
# 949                   두릅
# 950           단무지(스틱단무지)
# 951           고구마(호박고구마)
# 952             김치(포기김치)
# 953           부지갱이(울릉도취)
# 954                   케일
# 955                   꽃빵
# 956           에이드(체리에이드)
# 957                   체리
# 958          에이드(오렌지에이드)
# 959           소시지(어육소시지)
# 960       팬케이크가루(핫케이크가루)
# 961           에이드(라임에이드)
# 962             호박(조선호박)
# 963              차(오미자차)
# 964                  크림빵
# 965               차(대추차)
# 966               차(모과차)
# 967           과채주스(레몬과즙)
# 968          녹차(현미녹차침출액)
# 969                  땅두릅
# 970             머핀(치즈머핀)
# 971                  방아잎
# 972           김치(무말랭이김치)
# 973         경단(찹쌀경단, 당고)
# 974             분말(설탕분말)
# 975             두부(옛맛두부)
# 976                게(닭게)
# 977                  실고추
# 978                 비트뿌리
# 979                꽁치통조림
# 980                  달고기
# 981            식혜(단호박식혜)
# 982           샐러드(감자샐러드)
# 983                  자장면
# 984             녹색완두콩통조림
# 985                  호박싹
# 986                  양장피
# 987           감(홍시, 대봉시)
# 988                 맛조개살
# 989                  비트잎
# 990         육수(가다랑어삶은육수)
# 991         새우살(흰다리왕새우살)
# 992              녹차(잎녹차)
# 993           수제비(감자수제비)
# 994                  호박잎
# 995                   딤섬
# 996         시리얼(그래놀라시리얼)
# 997           무쌈(석류매실무쌈)
# 998             복숭아황도통조림
# 999         발효유(짜먹는요구르트)
# 1000          고구마(자색고구마)
# 1001            부침가루(메밀)
# 1002                슈크림빵
# 1003        동그랑땡(해물동그랑땡)
# 1004        동그랑땡(새우동그랑땡)
# 1005         목이버섯(흰목이버섯)
# 1006                 레몬청
# 1007              찹쌀(홍미)
# 1008                고추냉이
# 1009     튀김(감자튀김(해쉬브라운))
# 1010                  호떡
# 1011           새우(각시흰새우)
# 1012                 산수유
# 1013            주스(망고주스)
# 1014                키위원액
# 1015                미숫가루
# 1016          누룽지(현미누룽지)
# 1017          피클(모둠채소피클)
# 1018              차(국화차)
# 1019         소시지(스모크비엔나)
# 1020      단무지(온달슬라이스단무지)
# 1021              라이스페이퍼
# 1022                중화소스
# 1023          돈가스(치즈돈가스)
# 1024            튀김(새우튀김)
# 1025           콩가루(땅콩가루)
# 1026          완자(두부해물완자)
# 1027              꿀(토종꿀)
# 1028                  고비
# 1029             젓(어리굴젓)
# 1030                애플민트
# 1031                  치자
# 1032           만두(김치왕만두)
# 1033             김치(섞박지)
# 1034                  락교
# 1035                  주스
# 1036            대합살(백합살)
# 1037              팥(검정팥)
# 1038               깻잎지절임
# 1039                  박대
# 1040              무쌈(녹차)
# 1041             근대(적근대)
# 1042        케이크(티라미수케이크)
# 1043      어묵(매화, 앵두무늬어묵)
# 1044         에이드(청포도에이드)
# 1045            식혜(메밀식혜)
# 1046           병아리콩(차나달)
# 1047                베이컨칩
# 1048          군만두(피자군만두)
# 1049     시리얼(곡물(옥수수)시리얼)
# 1050                  조기
# 1051                메밀장국
# 1052            머핀(초코머핀)
# 1053                  머핀
# 1054             떡(미니절편)
# 1055              젓(낙지젓)
# 1056     시리얼(코코아(초코)시리얼)
# 1057        컵케이크(초코컵케이크)
# 1058         복합조미식품(혼다시)
# 1059             어묵(어묵바)
# 1060                삭힌고추
# 1061         분말(양송이수프분말)
# 1062             장어(갯장어)
# 1063                달걀말이
# 1064           피클(생강초절임)
# 1065         에이드(복숭아에이드)
# 1066           고구마(밤고구마)
# 1067             젓(독새우젓)
# 1068     튀김(감자튀김(스마일감자))
# 1069                순살치킨
# 1070                모둠견과
# 1071                로즈마리
# 1072     스테이크(언양식갈비스테이크)
# 1073               불고기소스
# 1074    데리야끼소스(일식데리야끼소스)
# 1075        파프리카(미니파프리카)
# 1076                 단팥빵
# 1077          찐빵(꼬마단팥찐빵)
# 1078                 팥앙금
# 1079           두부(검은깨두부)
# 1080          초콜릿(새알초콜릿)
# 1081   호박(애호박고지(애호박오가리))
# 1082              젓(창란젓)
# 1083            젓(모시조개젓)
# 1084                  카레
# 1085                 코코넛
# 1086                  라임
# 1087          공심채(모닝글로리)
# 1088              감귤(밀감)
# 1089            치즈(가공치즈)
# 1090           우유(고칼슘우유)
# 1091           푸딩(오렌지푸딩)
# 1092            푸딩(셔벗푸딩)
# 1093                  푸딩
# 1094            푸딩(리치푸딩)
# 1095            푸딩(키위푸딩)
# 1096              귤(한라봉)
# 1097              귤(천혜향)
# 1098            키위(골드키위)
# 1099           키위(그린참다래)
# 1100             사과(아오리)
# 1101           주스(복숭아주스)
# 1102                망고스틴
# 1103        혼합주스(딸기석류주스)
# 1104                매실음료
# 1105              포도(머루)
# 1106              포도(거봉)
# 1107            주스(감귤주스)
# 1108        과채주스(사과농축과즙)
# 1109            주스(당근주스)
# 1110           주스(토마토주스)
# 1111            김치(깻잎김치)
# 1112   조각케이크(생크림과일조각케이크)
# 1113                떡케이크
# 1114    조각케이크(레드벨벳조각케이크)
# 1115                  율무
# 1116             튀김(양파링)
# 1117             조기(백조기)
# 1118          핫도그(미니핫도그)
# 1119        미트볼(돼지고기미트볼)
# 1120           쌀가루(백미가루)
# 1121                  닭발
# 1122          어묵(잡채말이어묵)
# 1123                포도씨유
# 1124             조개(살조개)
# 1125                한우우족
# 1126               다시마튀각
# 1127                  실치
# 1128             아이스딸기퓨레
# 1129       돈가스(고구마치즈돈가스)
# 1130                연어훈제
# 1131                  새알
# 1132            팥앙금(붉은색)
# 1133                  참김
# 1134                  머위
# 1135                쌀보리순
# 1136         팥(계피팥(회색팥))
# 1137            산적(고기산적)
# 1138           참다랑어유지통조림
# 1139      토마토(주황대추방울토마토)
# 1140           돼지고기햄(로스)
# 1141            수프(채소수프)
# 1142            가쓰오부시 과립
# 1143       부추(호부추(중국부추))
# 1144                레몬소스
# 1145               하이스가루
# 1146         유채(동초, 겨울초)
# 1147         어린잎채소(베이비잎)
# 1148                라디키오
# 1149     과채주스(패션후르츠천연과즙)
# 1150              머스터드소스
# 1151            된장(메주된장)
# 1152             맥주(흑맥주)
# 1153             딸기(산딸기)
# 1154            식초(포도식초)
# 1155               발사믹소스
# 1156                 세이지
# 1157             백리향(타임)
# 1158             조청(쌀조청)
# 1159                모둠새싹
# 1160              혼합과일음료
# 1161                  분말
# 1162                 고추씨
# 1163           크림(경휘핑크림)
# 1164            육수(닭뼈육수)
# 1165          주스(파인애플주스)
# 1166           오리고기(통오리)
# 1167        유채(동초, 겨울초)잎
# 1168          토마토(완숙토마토)
# 1169                  인삼
# 1170    주스(블러드오렌지파인애플주스)
# 1171            배추(솎음배추)
# 1172          바질가루(바실가루)
# 1173          시럽(단풍나무시럽)
# 1174           장아찌(무장아찌)
# 1175                 소시지
# 1176                 콩국물
# 1177                   딜
# 1178          드레싱(유자드레싱)
# 1179                 메로살
# 1180            죽순통조림(홀)
# 1181               키조개관자
# 1182     호박(호박고지(호박오가리))
# 1183              묵(건조묵)
# 1184               우뭇가사리
# 1185             해파리냉채소스
# 1186                 씀바귀
# 1187                모둠채소
# 1188               무(왜무)
# 1189           깻잎나물(깨나물)
# 1190         크림(45% 유지방)
# 1191              곤약(판형)
# 1192             달걀(유정란)
# 1193              젓(멸치젓)
# 1194              감귤(조생)
# 1195            참다랑어(참치)
# 1196                 복숭아
# 1197            마요네즈(난황)
# 1198        떡볶이떡(모양떡볶이떡)
# 1199           고추장(찰고추장)
# 1200            감자(대지감자)
# 1201              찹쌀꿔바로우
# 1202             만두(닭만두)
# 1203          크로켓(카레크로켓)
# 1204              차(유자차)
# 1205            연유(탈지연유)
# 1206         김치(무배추나박김치)
# 1207             기장(찰기장)
# 1208         떡볶이떡(밀떡볶이떡)
# 1209               떡볶이소스
# 1210        스파게티소스(미트소스)
# 1211        초고추장(요리초고추장)

# %%
# 검색시 기본적인 식재료 먼저 가져오기 위해 괄호 삭제
used_name['식재료명']=used_name['식재료명'].str.replace(r'\s*\(.*?\)', '', regex=True)
used_name['식재료명']
# Out:
# 0                 새우
# 1                참기름
# 2              해바라기씨
# 3                 물엿
# 4                 간장
# 5              혼합식용유
# 6                 설탕
# 7                  깨
# 8                 마늘
# 9                 멥쌀
# 10                달걀
# 11               양배추
# 12               오징어
# 13               새우살
# 14             돈가스소스
# 15              부침가루
# 16              숙주나물
# 17                양파
# 18                 파
# 19               콩기름
# 20               김가루
# 21                김치
# 22                김치
# 23                김치
# 24                사과
# 25               바나나
# 26              토마토)
# 27              마요네즈
# 28                치즈
# 29                설탕
# 30               건포도
# 31                땅콩
# 32                소금
# 33                달걀
# 34                당근
# 35           닭가슴살파우치
# 36              게맛살채
# 37                소금
# 38                김치
# 39                보리
# 40                보리
# 41                호박
# 42                상추
# 43               파스타
# 44            스파게티소스
# 45               토마토
# 46            토마토통조림
# 47            토마토통조림
# 48                피망
# 49              표고버섯
# 50             양송이버섯
# 51                분말
# 52                육수
# 53                소면
# 54               깐달걀
# 55                무쌈
# 56                오이
# 57              고춧가루
# 58              팽이버섯
# 59                피망
# 60             죽순통조림
# 61                부추
# 62               굴소스
# 63                전분
# 64                 파
# 65                후추
# 66                소금
# 67            큰느타리버섯
# 68                간장
# 69                물엿
# 70                배추
# 71                 무
# 72               콩가루
# 73                된장
# 74               다시마
# 75                두부
# 76                냉이
# 77               고추)
# 78               고추)
# 79                분말
# 80                감자
# 81              송이버섯
# 82               완두콩
# 83              동그랑땡
# 84                두부
# 85               청국장
# 86               고추)
# 87                소금
# 88                완자
# 89                멥쌀
# 90               돌나물
# 91                달래
# 92               고사리
# 93               도라지
# 94               깨소금
# 95               매생이
# 96                생강
# 97                배추
# 98               고추장
# 99               수제비
# 100             들깨가루
# 101               간장
# 102              어육햄
# 103             브로콜리
# 104         허니머스터드소스
# 105             참깨가루
# 106              옹심이
# 107               미역
# 108             파프리카
# 109             파프리카
# 110             파프리카
# 111              청경채
# 112            고추씨기름
# 113               고추
# 114               식초
# 115              시금치
# 116               간장
# 117              들기름
# 118               김치
# 119             찹쌀가루
# 120          녹두빈대떡가루
# 121            옥수수기름
# 122                김
# 123             후리카케
# 124              빵가루
# 125           스테이크소스
# 126               소금
# 127              밀가루
# 128               유부
# 129             석이버섯
# 130               식초
# 131               후추
# 132           애느타리버섯
# 133             후춧가루
# 134              취나물
# 135               된장
# 136              콩나물
# 137               배추
# 138              매실청
# 139                젓
# 140              장아찌
# 141               한우
# 142               맛술
# 143               바질
# 144                꿀
# 145             올리브유
# 146              아몬드
# 147              닭고기
# 148               카레
# 149               우유
# 150               분말
# 151               사과
# 152             파인애플
# 153              토마토
# 154               포도
# 155               키위
# 156               식혜
# 157             오리훈제
# 158              드레싱
# 159                젓
# 160                햄
# 161               피클
# 162               피클
# 163              파스타
# 164           옥수수통조림
# 165            토마토케첩
# 166               후추
# 167             돼지고기
# 168              닭고기
# 169                떡
# 170              양상추
# 171              치커리
# 172              양배추
# 173             올리고당
# 174               식초
# 175               우유
# 176               식초
# 177             파프리카
# 178             파인애플
# 179               치즈
# 180              밀가루
# 181               당면
# 182             목이버섯
# 183              참나물
# 184               홍합
# 185               조개
# 186               죽순
# 187             갑오징어
# 188             무시래기
# 189               육수
# 190               육우
# 191              토마토
# 192              로메인
# 193             적겨자잎
# 194               비트
# 195              발효유
# 196               깻잎
# 197             아보카도
# 198          파인애플통조림
# 199             과즙음료
# 200              순무잎
# 201              고추장
# 202              드레싱
# 203              치커리
# 204             블루베리
# 205               김치
# 206               멸치
# 207               물엿
# 208               호두
# 209               전병
# 210            감귤통조림
# 211              드레싱
# 212              장아찌
# 213              바게트
# 214              떡갈비
# 215           데리야끼소스
# 216              부추)
# 217               두부
# 218             돼지고기
# 219             돼지잡뼈
# 220               호박
# 221               크림
# 222              수제비
# 223               멸치
# 224               연어
# 225               포도
# 226               레몬
# 227               주스
# 228              뱅어포
# 229                떡
# 230               라면
# 231               멥쌀
# 232               명태
# 233              홍합살
# 234                젓
# 235               찹쌀
# 236               찹쌀
# 237           타르타르소스
# 238              드레싱
# 239               육수
# 240              조갯살
# 241               명태
# 242               새우
# 243              옥수수
# 244              오렌지
# 245              드레싱
# 246              수정과
# 247              통계피
# 248               설탕
# 249                잣
# 250               맛살
# 251               어묵
# 252               분말
# 253             사골국물
# 254               한우
# 255             대두콩)
# 256               귀리
# 257               기장
# 258               김치
# 259               김치
# 260               멥쌀
# 261            매실농축액
# 262               김치
# 263               식초
# 264               깨)
# 265              단무지
# 266              꽃맛살
# 267              단무지
# 268               멥쌀
# 269              곤드레
# 270               부추
# 271            고구마줄기
# 272                깨
# 273               근대
# 274               강황
# 275               만두
# 276               김치
# 277               우엉
# 278               육우
# 279            느타리버섯
# 280                배
# 281               생수
# 282               육우
# 283              치즈)
# 284               청주
# 285               육우
# 286             육우잡뼈
# 287               소금
# 288             돼지고기
# 289          데미글라스소스
# 290              셀러리
# 291             달걀지단
# 292             돼지고기
# 293              면실유
# 294              호박)
# 295         매끈이고둥통조림
# 296               가지
# 297                밤
# 298               연근
# 299             한우사골
# 300              소잡뼈
# 301               상추
# 302               김치
# 303                쑥
# 304         표고버섯플레이크
# 305              토란대
# 306              칼국수
# 307               멸치
# 308              쌀국수
# 309               육수
# 310                파
# 311              드레싱
# 312               육우
# 313              떡국떡
# 314               육우
# 315             떡볶이떡
# 316             칠리소스
# 317          토마토페이스트
# 318             적포도주
# 319              베이컨
# 320               버터
# 321             월계수잎
# 322              핫소스
# 323               치즈
# 324               배추
# 325               쑥갓
# 326               육우
# 327               육우
# 328                떡
# 329               육수
# 330               전분
# 331               육수
# 332           소불고기양념
# 333            우스터소스
# 334             백포도주
# 335               넥타
# 336             겨자소스
# 337               곤약
# 338           스파게티소스
# 339              또띠아
# 340               치즈
# 341               치즈
# 342               한우
# 343             후춧가루
# 344             핫도그빵
# 345               육우
# 346               고수
# 347               육우
# 348              소사골
# 349                소
# 350             한우잡뼈
# 351               은행
# 352            두반장소스
# 353           토마토통조림
# 354               정향
# 355               낙지
# 356               감자
# 357          숯불바비큐소스
# 358               토란
# 359              꼬막살
# 360               식빵
# 361              게맛살
# 362               크림
# 363              육수본
# 364               젓)
# 365              새우)
# 366             동그랑땡
# 367              주꾸미
# 368                밥
# 369              닭고기
# 370             알팔파싹
# 371            그릭요거트
# 372              올리브
# 373             돼지고기
# 374               고추
# 375                배
# 376             가자미살
# 377              콩가루
# 378             오리고기
# 379               어묵
# 380              닭고기
# 381               분말
# 382             마요네즈
# 383           겨자페이스트
# 384               부추
# 385               무싹
# 386             돼지고기
# 387             튀김가루
# 388               전분
# 389               삼치
# 390             돼지고기
# 391               한우
# 392        후르츠칵테일통조림
# 393               굴비
# 394               만두
# 395               한우
# 396                햄
# 397               한우
# 398            불고기양념
# 399               땅콩
# 400              닭고기
# 401              가자미
# 402              수리취
# 403              미더덕
# 404              미나리
# 405              다시마
# 406               멸치
# 407               조기
# 408               찹쌀
# 409               차조
# 410              모닝빵
# 411               장어
# 412              바지락
# 413              탕수육
# 414               식초
# 415               간장
# 416              피마자
# 417              미나리
# 418              고구마
# 419               연유
# 420               계피
# 421               보리
# 422             돼지고기
# 423                차
# 424               소주
# 425               후추
# 426               만두
# 427              닭고기
# 428              고등어
# 429             돼지고기
# 430               아욱
# 431              빵가루
# 432            오징어몸통
# 433             오리고기
# 434                팥
# 435              서리태
# 436               수수
# 437               송편
# 438             오리고기
# 439               무쌈
# 440              닭고기
# 441               대추
# 442               인삼
# 443                햄
# 444             바지락살
# 445               멸치
# 446               녹두
# 447             메밀국수
# 448               육수
# 449              치즈)
# 450               커피
# 451              시루떡
# 452           치킨튀김가루
# 453               새우
# 454              치즈볼
# 455               새알
# 456              발효유
# 457              크로켓
# 458               배추
# 459               분말
# 460              고추장
# 461               우동
# 462              호박)
# 463             고춧가루
# 464               곤약
# 465               약과
# 466              건고추
# 467             논우렁살
# 468               호박
# 469              삼치살
# 470               비지
# 471               우동
# 472          가쓰오우동장국
# 473               어묵
# 474          시리얼시리얼)
# 475             크랜베리
# 476              날치알
# 477              장아찌
# 478               한우
# 479              전복살
# 480             전복내장
# 481             돼지고기
# 482               어묵
# 483                게
# 484               파래
# 485            코코넛밀크
# 486              새우살
# 487               카레
# 488               수수
# 489              깻잎순
# 490               더덕
# 491              고추장
# 492                묵
# 493               찹쌀
# 494           양념치킨소스
# 495               달걀
# 496             코다리살
# 497                햄
# 498                묵
# 499               병어
# 500               새우
# 501           한우사골곰탕
# 502            돼지고기햄
# 503              소시지
# 504            탕수육소스
# 505               주스
# 506              소시지
# 507               치즈
# 508             햄버거빵
# 509              새우살
# 510              케이크
# 511               두부
# 512              베이글
# 513               치즈
# 514             초고추장
# 515             돼지등뼈
# 516              콜라비
# 517             탄산음료
# 518               된장
# 519               어묵
# 520               육수
# 521             혼합멸치
# 522               육수
# 523               어묵
# 524              북어채
# 525               된장
# 526                젓
# 527               조개
# 528              모자반
# 529              유자청
# 530              닭고기
# 531               소금
# 532              튀김)
# 533               양파
# 534              드레싱
# 535              돈가스
# 536               홍합
# 537               우유
# 538            콜리플라워
# 539           스파게티소스
# 540            튀김튀김)
# 541               춘장
# 542              파슬리
# 543             오레가노
# 544               푸딩
# 545               포도
# 546               딸기
# 547              콜라비
# 548                톳
# 549           무말랭이무침
# 550              황태채
# 551            사골엑기스
# 552              연두부
# 553               만두
# 554              떡국떡
# 555               분말
# 556              바질)
# 557             버터스틱
# 558             피시소스
# 559               주스
# 560               한우
# 561               크림
# 562               달걀
# 563              동태살
# 564             메추리알
# 565               한우
# 566              머위대
# 567              연두부
# 568                게
# 569           닭가슴살치킨
# 570              춘장)
# 571               오이
# 572              미트볼
# 573               소금
# 574              된장)
# 575               다채
# 576             고등어살
# 577                햄
# 578              새우볼
# 579             임연수살
# 580               우유
# 581              치커리
# 582            죽순통조림
# 583         양송이버섯통조림
# 584               당귀
# 585               주스
# 586               수박
# 587               곤약
# 588               명란
# 589            닭다리훈제
# 590             조랭이떡
# 591               쫄면
# 592               어묵
# 593               대구
# 594               오이
# 595              탕수육
# 596         마일드참치통조림
# 597            소갈비양념
# 598              탕수육
# 599              전분)
# 600              소시지
# 601             스테이크
# 602                떡
# 603              소라살
# 604              치즈)
# 605               수프
# 606             스테이크
# 607            토마토소스
# 608                게
# 609               볼락
# 610                떡
# 611               당면
# 612          스위트칠리소스
# 613              복숭아
# 614               감귤
# 615            참다랑어살
# 616          와사비페이스트
# 617              다채싹
# 618               물엿
# 619              튀김)
# 620              미트볼
# 621             샌드위치
# 622               어묵
# 623              군만두
# 624              돈가스
# 625               국수
# 626             땅콩버터
# 627              오징어
# 628              닭고기
# 629              잔대싹
# 630                감
# 631              아귀살
# 632               만두
# 633            돼지고기햄
# 634              양상추
# 635       홀그레인머스터드소스
# 636               석류
# 637             가다랑어
# 638               식초
# 639               어묵
# 640              갯나물
# 641              골뱅이
# 642               당근
# 643               육수
# 644               어묵
# 645            치킨파우더
# 646              올리브
# 647              연어살
# 648              드레싱
# 649              오렌지
# 650               두부
# 651                잼
# 652               만두
# 653             비름나물
# 654               쌈장
# 655               고추
# 656              깐호두
# 657              토종닭
# 658             꼬시래기
# 659               오이
# 660               만두
# 661              닭꼬치
# 662             무말랭이
# 663                묵
# 664              소시지
# 665             파래돌김
# 666               꼬막
# 667               소금
# 668          블루베리통조림
# 669        아스파라거스통조림
# 670              소시지
# 671              임연수
# 672               상추
# 673             미꾸라지
# 674             산초가루
# 675              마늘종
# 676             미역줄기
# 677               갈치
# 678               리치
# 679           돼지갈비양념
# 680               치즈
# 681            브로콜리싹
# 682               파래
# 683             치킨텐더
# 684              유채싹
# 685               당면
# 686               주스
# 687              복분자
# 688               김치
# 689               김치
# 690             옥수수알
# 691             크림수프
# 692               소면
# 693               인삼
# 694               튀김
# 695             스테이크
# 696             동그랑땡
# 697              장아찌
# 698              동태알
# 699              대구알
# 700             명태곤이
# 701               어묵
# 702             찹쌀가루
# 703              진달래
# 704             시금치)
# 705                마
# 706               분말
# 707                젓
# 708               분말
# 709             청국장)
# 710          중화풍볶음소스
# 711              소시지
# 712             스테이크
# 713             참소라살
# 714            바비큐소스
# 715               상추
# 716               명태
# 717                묵
# 718             오만둥이
# 719              핫도그
# 720               망고
# 721             혼합주스
# 722               명태
# 723           사워크림소스
# 724               해삼
# 725             스테이크
# 726             피자소스
# 727              미트볼
# 728         고추냉이페이스트
# 729             스테이크
# 730             생선가스
# 731              돈가스
# 732            찰옥수수알
# 733            탄두리치킨
# 734              군만두
# 735              강낭콩
# 736               꽁치
# 737              또띠아
# 738            마늘바게트
# 739              갈치살
# 740               전복
# 741              동죽살
# 742              호박씨
# 743               명태
# 744              소시지
# 745                젓
# 746              닭고기
# 747             메밀가루
# 748             장아찌)
# 749                젓
# 750              마른김
# 751              백진미
# 752              해파리
# 753               파래
# 754            넝쿨강낭콩
# 755                김
# 756                묵
# 757              명엽채
# 758               소면
# 759             동태곤이
# 760              소시지
# 761              동태포
# 762              현미유
# 763            만가닥버섯
# 764                햄
# 765               젓)
# 766               두부
# 767              가자미
# 768              와사비
# 769              호밀빵
# 770             샌드위치
# 771            닭고기훈제
# 772               전복
# 773              드레싱
# 774             샌드위치
# 775              김자반
# 776             샌드위치
# 777             샌드위치
# 778               우유
# 779              닭갈비
# 780              발효유
# 781               주스
# 782            흑임자가루
# 783              누룽지
# 784             곤약국수
# 785               어묵
# 786               춘권
# 787                김
# 788              풋마늘
# 789              대구살
# 790          가다랑어통조림
# 791              새우살
# 792             소시지)
# 793     홀커넬스타일옥수수통조림
# 794              소시지
# 795               순대
# 796              육수본
# 797              소시지
# 798               튀김
# 799              군만두
# 800               멜론
# 801            모시조개살
# 802               동부
# 803               찹쌀
# 804              렌틸콩
# 805            아이스크림
# 806           명이나물절임
# 807              콩자반
# 808               열무
# 809              시루떡
# 810             떡꼬치떡
# 811                떡
# 812              핫도그
# 813             소보루빵
# 814            페이스트리
# 815               냉면
# 816              닭꼬치
# 817               자두
# 818              꽈배기
# 819              핫도그
# 820              군만두
# 821              옥수수
# 822               식빵
# 823              또띠아
# 824               수프
# 825               수프
# 826               문어
# 827              유채)
# 828         와인숙성돼지훈제
# 829              마늘빵
# 830              포항초
# 831              방어살
# 832              재첩살
# 833              포도)
# 834               어묵
# 835               순대
# 836              대두콩
# 837                묵
# 838              무화과
# 839              에이드
# 840              튀김)
# 841              크로켓
# 842              파스타
# 843              다슬기
# 844             돌김자반
# 845               멸치
# 846               완자
# 847               튀김
# 848              시루떡
# 849              오이)
# 850               돌김
# 851               상추
# 852               국수
# 853                떡
# 854          데리야끼닭꼬치
# 855               햄)
# 856              시리얼
# 857          시리얼시리얼)
# 858                차
# 859               완자
# 860               피클
# 861               피클
# 862              고춧잎
# 863               우유
# 864                포
# 865               유자
# 866           아스파라거스
# 867              어묵)
# 868              드레싱
# 869             과즙음료
# 870              닭고기
# 871               멜론
# 872              단무지
# 873               와플
# 874              초코볼
# 875               시럽
# 876               오이
# 877                굴
# 878              간장)
# 879               우동
# 880               주스
# 881              돈가스
# 882            돈가스소스
# 883               산적
# 884             혼합주스
# 885               식초
# 886               주스
# 887             방풍나물
# 888               앵두
# 889               완자
# 890           타코야끼소스
# 891             꿔바로우
# 892             올리고당
# 893                감
# 894               분말
# 895               주스
# 896               햄)
# 897             우엉조림
# 898             탄산음료
# 899               김치
# 900               두릅
# 901               어묵
# 902               어묵
# 903               어묵
# 904             순무뿌리
# 905               미역
# 906                떡
# 907                감
# 908               재첩
# 909            오리불고기
# 910               멥쌀
# 911               두유
# 912              핫도그
# 913               새우
# 914            돼지고기햄
# 915               김치
# 916              단무지
# 917             밤통조림
# 918               주스
# 919            아이스홍시
# 920               튀김
# 921                차
# 922               치즈
# 923             새우가스
# 924             클로렐라
# 925           갑오징어몸통
# 926              치즈)
# 927             피자소스
# 928               냉면
# 929               식초
# 930               두부
# 931                차
# 932             카레소스
# 933               주스
# 934               자몽
# 935               미역
# 936               만주
# 937               곤이
# 938              탕수육
# 939            깻잎지절임
# 940              장아찌
# 941              원추리
# 942                차
# 943              복숭아
# 944               참외
# 945         돼지고기햄통조림
# 946             치킨가스
# 947             캐슈너트
# 948              드레싱
# 949               두릅
# 950              단무지
# 951              고구마
# 952               김치
# 953             부지갱이
# 954               케일
# 955               꽃빵
# 956              에이드
# 957               체리
# 958              에이드
# 959              소시지
# 960           팬케이크가루
# 961              에이드
# 962               호박
# 963                차
# 964              크림빵
# 965                차
# 966                차
# 967             과채주스
# 968               녹차
# 969              땅두릅
# 970               머핀
# 971              방아잎
# 972               김치
# 973               경단
# 974               분말
# 975               두부
# 976                게
# 977              실고추
# 978             비트뿌리
# 979            꽁치통조림
# 980              달고기
# 981               식혜
# 982              샐러드
# 983              자장면
# 984         녹색완두콩통조림
# 985              호박싹
# 986              양장피
# 987                감
# 988             맛조개살
# 989              비트잎
# 990               육수
# 991              새우살
# 992               녹차
# 993              수제비
# 994              호박잎
# 995               딤섬
# 996              시리얼
# 997               무쌈
# 998         복숭아황도통조림
# 999              발효유
# 1000             고구마
# 1001            부침가루
# 1002            슈크림빵
# 1003            동그랑땡
# 1004            동그랑땡
# 1005            목이버섯
# 1006             레몬청
# 1007              찹쌀
# 1008            고추냉이
# 1009             튀김)
# 1010              호떡
# 1011              새우
# 1012             산수유
# 1013              주스
# 1014            키위원액
# 1015            미숫가루
# 1016             누룽지
# 1017              피클
# 1018               차
# 1019             소시지
# 1020             단무지
# 1021          라이스페이퍼
# 1022            중화소스
# 1023             돈가스
# 1024              튀김
# 1025             콩가루
# 1026              완자
# 1027               꿀
# 1028              고비
# 1029               젓
# 1030            애플민트
# 1031              치자
# 1032              만두
# 1033              김치
# 1034              락교
# 1035              주스
# 1036             대합살
# 1037               팥
# 1038           깻잎지절임
# 1039              박대
# 1040              무쌈
# 1041              근대
# 1042             케이크
# 1043              어묵
# 1044             에이드
# 1045              식혜
# 1046            병아리콩
# 1047            베이컨칩
# 1048             군만두
# 1049         시리얼시리얼)
# 1050              조기
# 1051            메밀장국
# 1052              머핀
# 1053              머핀
# 1054               떡
# 1055               젓
# 1056         시리얼시리얼)
# 1057            컵케이크
# 1058          복합조미식품
# 1059              어묵
# 1060            삭힌고추
# 1061              분말
# 1062              장어
# 1063            달걀말이
# 1064              피클
# 1065             에이드
# 1066             고구마
# 1067               젓
# 1068             튀김)
# 1069            순살치킨
# 1070            모둠견과
# 1071            로즈마리
# 1072            스테이크
# 1073           불고기소스
# 1074          데리야끼소스
# 1075            파프리카
# 1076             단팥빵
# 1077              찐빵
# 1078             팥앙금
# 1079              두부
# 1080             초콜릿
# 1081             호박)
# 1082               젓
# 1083               젓
# 1084              카레
# 1085             코코넛
# 1086              라임
# 1087             공심채
# 1088              감귤
# 1089              치즈
# 1090              우유
# 1091              푸딩
# 1092              푸딩
# 1093              푸딩
# 1094              푸딩
# 1095              푸딩
# 1096               귤
# 1097               귤
# 1098              키위
# 1099              키위
# 1100              사과
# 1101              주스
# 1102            망고스틴
# 1103            혼합주스
# 1104            매실음료
# 1105              포도
# 1106              포도
# 1107              주스
# 1108            과채주스
# 1109              주스
# 1110              주스
# 1111              김치
# 1112           조각케이크
# 1113            떡케이크
# 1114           조각케이크
# 1115              율무
# 1116              튀김
# 1117              조기
# 1118             핫도그
# 1119             미트볼
# 1120             쌀가루
# 1121              닭발
# 1122              어묵
# 1123            포도씨유
# 1124              조개
# 1125            한우우족
# 1126           다시마튀각
# 1127              실치
# 1128         아이스딸기퓨레
# 1129             돈가스
# 1130            연어훈제
# 1131              새알
# 1132             팥앙금
# 1133              참김
# 1134              머위
# 1135            쌀보리순
# 1136              팥)
# 1137              산적
# 1138       참다랑어유지통조림
# 1139             토마토
# 1140           돼지고기햄
# 1141              수프
# 1142        가쓰오부시 과립
# 1143             부추)
# 1144            레몬소스
# 1145           하이스가루
# 1146              유채
# 1147           어린잎채소
# 1148            라디키오
# 1149            과채주스
# 1150          머스터드소스
# 1151              된장
# 1152              맥주
# 1153              딸기
# 1154              식초
# 1155           발사믹소스
# 1156             세이지
# 1157             백리향
# 1158              조청
# 1159            모둠새싹
# 1160          혼합과일음료
# 1161              분말
# 1162             고추씨
# 1163              크림
# 1164              육수
# 1165              주스
# 1166            오리고기
# 1167             유채잎
# 1168             토마토
# 1169              인삼
# 1170              주스
# 1171              배추
# 1172            바질가루
# 1173              시럽
# 1174             장아찌
# 1175             소시지
# 1176             콩국물
# 1177               딜
# 1178             드레싱
# 1179             메로살
# 1180           죽순통조림
# 1181           키조개관자
# 1182             호박)
# 1183               묵
# 1184           우뭇가사리
# 1185         해파리냉채소스
# 1186             씀바귀
# 1187            모둠채소
# 1188               무
# 1189            깻잎나물
# 1190              크림
# 1191              곤약
# 1192              달걀
# 1193               젓
# 1194              감귤
# 1195            참다랑어
# 1196             복숭아
# 1197            마요네즈
# 1198            떡볶이떡
# 1199             고추장
# 1200              감자
# 1201          찹쌀꿔바로우
# 1202              만두
# 1203             크로켓
# 1204               차
# 1205              연유
# 1206              김치
# 1207              기장
# 1208            떡볶이떡
# 1209           떡볶이소스
# 1210          스파게티소스
# 1211            초고추장
# Name: 식재료명, dtype: object

# %%
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote

# 인증키
key = 'Hy7rvWaXikWqGQCbQxWU9Hyzj5AXoFgds%2ByZ1knY9F%2FfEON853OPBRo8OYpKYvCiEB3r8uYZ1ZpU4EMpppX%2B8g%3D%3D'

# 결과 리스트 초기화
nutrition_info = []

# 총 데이터 개수
total = len(used_name['식재료명'])

# 시간 측정 시작
start_time = time.time()

# 데이터 처리 및 API 호출
for idx, food in enumerate(used_name['식재료명'].tolist(), start=1):
    # 진행 상태 출력 (1% 단위)
    if idx % (total // 100) == 0:  # 전체의 1%마다
        progress = (idx / total) * 100
        print(f"진행률: {progress:.0f}% 완료")

    # API 호출 URL 생성
    url = f'https://apis.data.go.kr/1471000/FoodNtrCpntDbInfo01/getFoodNtrCpntDbInq01?serviceKey={key}&numOfRows=100&type=xml&FOOD_NM_KR={quote(food)}'
    response = requests.get(url)
    
    if response.status_code == 200:  # API 호출 성공
        soup = BeautifulSoup(response.text, "xml")
        itemLists = soup.find_all('item')
        
        for itemList in itemLists:
            try:
                FOOD_NM_KR = itemList.find('FOOD_NM_KR').text
                AMT_NUM1 = itemList.find('AMT_NUM1').text
                AMT_NUM7 = itemList.find('AMT_NUM7').text
                AMT_NUM3 = itemList.find('AMT_NUM3').text
                AMT_NUM4 = itemList.find('AMT_NUM4').text
                NUTRI_AMOUNT_SERVING=itemList.find('NUTRI_AMOUNT_SERVING').text
                Z10500 = itemList.find('Z10500').text

                nutrition_info.append([FOOD_NM_KR, AMT_NUM1, AMT_NUM7, AMT_NUM3, AMT_NUM4,NUTRI_AMOUNT_SERVING,Z10500])
            except AttributeError:
                # 일부 데이터가 없을 경우 대비
                continue
    else:
        print(f"Failed to fetch data for {food}. HTTP Status Code: {response.status_code}")

# 시간 측정 종료
end_time = time.time()

# 최종 완료 메시지 및 소요 시간 출력
print("처리 완료")
print(f"총 소요 시간: {end_time - start_time:.6f} 초")

# 데이터프레임 생성
df = pd.DataFrame(nutrition_info, columns=['식재료명', '에너지(kcal)', '탄수화물', '단백질', '지방','1회 섭취 참고량','식품중량'])

# 결과 출력
df

# %%
# api 사용후 결과물 csv파일로 저장

df.to_csv(r'../data/식재료별영양소함량.csv',index=False,encoding='utf-8')

# %%
# 공공데이터포털에서 가져온 csv파일에서 필요한 데이터만 가져오기
columns_to_select = ['식품명','에너지(kcal)','탄수화물(g)','단백질(g)','지방(g)']
df_nute_farm = pd.read_csv(r'../data/농산물.csv',encoding='utf_8',usecols=columns_to_select)
df_nute_aqua = pd.read_csv(r'../data/수산물.csv',encoding='utf_8',usecols=columns_to_select)

df_nute_aqua.rename(columns={'식품명':'식재료명'},inplace=True)
df_nute_farm.rename(columns={'식품명':'식재료명'},inplace=True)

# %%
display(df_nute_farm)
display(df_nute_aqua)
# Out:
#                  식재료명  에너지(kcal)  단백질(g)  지방(g)  탄수화물(g)
# 0        귀리_겉귀리_도정_생것        388    9.88   8.84    68.03
# 1        귀리_쌀귀리_도정_생것        388   11.14   8.90    66.66
# 2     귀리_쌀귀리+대양_도정_생것        386   11.51   8.78    66.10
# 3     귀리_쌀귀리+조양_도정_생것        390   10.78   9.01    67.23
# 4            기장_도정_생것        360   11.20   1.90    74.60
# ...               ...        ...     ...    ...      ...
# 1847   흰점박이 꽃무지_유충_생것        122   15.78   5.20     2.90
# 1848  흰점박이 꽃무지_유충_말린것        463   54.13  18.52    19.99
# 1849     장수풍뎅이_유충_말린것        502   44.62  27.21    19.55
# 1850       팽창제_효모_말린것        307   37.10   6.80    43.10
# 1851             로열젤리        104   14.29   1.40    12.82
#
# [1852 rows x 5 columns]
#                                식재료명  에너지(kcal)  단백질(g)  지방(g)  탄수화물(g)
# 0               가라지류_가라지_육_생것_여수_6월         78   14.81   1.30     0.69
# 1     가리비류_가리비_관자(패주)_삶아서 말린것_대표_평균        334   65.70   1.40     7.60
# 2          가리비류_가리비_관자(패주)_생것_대표_평균         91   16.90   0.30     3.50
# 3         가리비류_가리비_관자(패주)_얼린것_대표_평균        117   20.80   0.80     2.40
# 4              가리비류_가리비_육_말린것_대표_평균        387   77.60   0.40     4.40
# ...                             ...        ...     ...    ...      ...
# 1746              횟대류_도치_육_생것_대표_평균         69    7.20   3.00     0.90
# 1747      횟대류_도치_육_소금에 절여 말린것_대표_평균        313   44.80   9.80     0.20
# 1748            횟대류_빨간횟대_육_생것_부산_4월         74   17.10   0.10     0.31
# 1749                 흑해삼_육_생것_포항_3월         27    3.41   0.38     2.23
# 1750                 히메치_육_생것_부산_7월         99   20.90   1.10     0.00
#
# [1751 rows x 5 columns]

# %%
df_nute_farm.to_csv(r'../data/식재료별영양소함량_농산물.csv',index=False,encoding='utf-8')
df_nute_aqua.to_csv(r'../data/식재료별영양소함량_수산물.csv',index=False,encoding='utf-8')

# %%
# 이 파일들은 기존에 계획했던 것보다 빨리 끝나면 추가로 해보려고 불러온 에너지 이외의 탄단지 데이터
