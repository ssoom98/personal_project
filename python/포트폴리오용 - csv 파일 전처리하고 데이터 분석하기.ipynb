# %%
import pandas as pd
recipe_list=pd.read_csv(r'../data/recipe_list.csv',encoding='utf_8')
recipe_list
# Out:
#       레시피구분        레시피명                열량          식재료명  식재료양
# 0       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal       새우(꽃새우)    8g
# 1       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal           참기름    4g
# 2       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal         해바라기씨    3g
# 3       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal            물엿  1.5g
# 4       볶음류  건새우해바라기씨볶음  열량 : 100.91 kcal      간장(양조간장)    1g
# ...     ...         ...               ...           ...   ...
# 41574    국류     김치콩비지찌개  열량 : 102.46 kcal   멸치(큰멸치, 대멸)    2g
# 41575    국류     김치콩비지찌개  열량 : 102.46 kcal            마늘    1g
# 41576    국류     김치콩비지찌개  열량 : 102.46 kcal            생강  0.1g
# 41577   무침류   브로콜리/초고추장    열량 : 33.9 kcal          브로콜리   40g
# 41578   무침류   브로콜리/초고추장    열량 : 33.9 kcal  초고추장(요리초고추장)   10g
#
# [41579 rows x 5 columns]

# %%
# Out:
#                                              식재료명  식재료양
# 레시피구분 레시피명     열량
# 구이류   가자미구이    열량 : 168.71 kcal 0             가자미   80g
#                                 1       후춧가루(검은색)  0.1g
#                                 2         소금(천일염)    1g
#                                 3        콩기름(대두유)    3g
#                                 4             밀가루   10g
# ...                                           ...   ...
# 튀김류   흑임자누룽지치킨 열량 : 316.96 kcal 8              후추    1g
#                                 9        분말(겨자분말)    2g
#                                 10          흑임자가루    3g
#                                 11  닭고기(가슴살, 안심살)   30g
#                                 12       닭고기(다리살)   40g
#
# [41579 rows x 2 columns]

# %%
# Out:
#    레시피구분
# 0    볶음류
# 1     밥류
# 2    김치류
# 3    무침류
# 4    부침류
# 5     면류
# 6    조림류
# 7     국류
# 8    구이류
# 9     찜류
# 10   튀김류
# 11    기타
# 12   보조식
# 13   소스류
# 14    빵류
# 15    죽류

# %%
# 레시피 구분별로 평균 열량 뽑아서 식단 조합 생각해보기 
학습후 적용하기 위해서 나중에 생각 아이디어 떠오를시 재시작
# Out:
#   Cell In[1], line 2
#     학습후 적용하기 위해서 나중에 생각 아이디어 떠오를시 재시작
#         ^
# SyntaxError: invalid syntax
